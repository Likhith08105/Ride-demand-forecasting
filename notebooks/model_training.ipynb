# %% [markdown]
# # Model training notebook
# This notebook reproduces what `train.py` does and is an interactive place to experiment with features.

# %%
import pandas as pd
df = pd.read_csv('../data/yellow_tripdata_2023-01.csv', parse_dates=['tpep_pickup_datetime'])
df['hour'] = df['tpep_pickup_datetime'].dt.hour
df['day_of_week'] = df['tpep_pickup_datetime'].dt.dayofweek
df_hourly = df.groupby(['day_of_week','hour']).size().reset_index(name='demand')
df_hourly.head()
